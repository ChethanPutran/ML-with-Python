# %% [markdown]
# # CODE TO CLASSIFY TRAFFIC SIGNS

# %% [markdown]
# Citation
#
# J. Stallkamp, M. Schlipsing, J. Salmen, and C. Igel. The German Traffic Sign Recognition Benchmark: A multi-class classification competition. In Proceedings of the IEEE International Joint Conference on Neural Networks, pages 1453–1460. 2011.
#
# @inproceedings{Stallkamp-IJCNN-2011,
#     author = {Johannes Stallkamp and Marc Schlipsing and Jan Salmen and Christian Igel},
#     booktitle = {IEEE International Joint Conference on Neural Networks},
#     title = {The {G}erman {T}raffic {S}ign {R}ecognition {B}enchmark: A multi-class classification competition},
#     year = {2011},
#     pages = {1453--1460}
# }

# %% [markdown]
# - ( 0, b'Speed limit (20km/h)') ( 1, b'Speed limit (30km/h)')
# - ( 2, b'Speed limit (50km/h)') ( 3, b'Speed limit (60km/h)')
# - ( 4, b'Speed limit (70km/h)') ( 5, b'Speed limit (80km/h)')
# - ( 6, b'End of speed limit (80km/h)') ( 7, b'Speed limit (100km/h)')
# - ( 8, b'Speed limit (120km/h)') ( 9, b'No passing')
# - (10, b'No passing for vehicles over 3.5 metric tons')
# - (11, b'Right-of-way at the next intersection') (12, b'Priority road')
# - (13, b'Yield') (14, b'Stop') (15, b'No vehicles')
# - (16, b'Vehicles over 3.5 metric tons prohibited') (17, b'No entry')
# - (18, b'General caution') (19, b'Dangerous curve to the left')
# - (20, b'Dangerous curve to the right') (21, b'Double curve')
# - (22, b'Bumpy road') (23, b'Slippery road')
# - (24, b'Road narrows on the right') (25, b'Road work')
# - (26, b'Traffic signals') (27, b'Pedestrians') (28, b'Children crossing')
# - (29, b'Bicycles crossing') (30, b'Beware of ice/snow')
# - (31, b'Wild animals crossing')
# - (32, b'End of all speed and passing limits') (33, b'Turn right ahead')
# - (34, b'Turn left ahead') (35, b'Ahead only') (36, b'Go straight or right')
# - (37, b'Go straight or left') (38, b'Keep right') (39, b'Keep left')
# - (40, b'Roundabout mandatory') (41, b'End of no passing')
# - (42, b'End of no passing by vehicles over 3.5 metric tons')

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# import libraries 
import pickle

import pandas as pd # Import Pandas for data manipulation using dataframes
import numpy as np # Import Numpy for data statistical analysis 
import matplotlib.pyplot as plt # Import matplotlib for data visualisation
import random

# %%
with open("./traffic-signs-data/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("./traffic-signs-data/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("./traffic-signs-data/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
y_train.shape
# Out:
# (34799,)

# %% [markdown]
# # IMAGE EXPLORATION

# %%
i = 1001
plt.imshow(X_train[i]) # Show images are not shuffled
y_train[i]
# Out:
# 36

# %% [markdown]
# # DATA PEPARATION

# %%
## Shuffle the dataset 
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %%
X_train_gray = np.sum(X_train/3, axis=3, keepdims=True)
X_test_gray  = np.sum(X_test/3, axis=3, keepdims=True)
X_validation_gray  = np.sum(X_validation/3, axis=3, keepdims=True)

# %%
X_train_gray_norm = (X_train_gray - 128)/128 
X_test_gray_norm = (X_test_gray - 128)/128
X_validation_gray_norm = (X_validation_gray - 128)/128

# %%
X_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
i = 610
plt.imshow(X_train_gray[i].squeeze(), cmap='gray')
plt.figure()
plt.imshow(X_train[i])

# %% [markdown]
# # MODEL TRAINING

# %%
# Import train_test_split from scikit library
# Import Keras
# import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard

# from subprocess import check_output
from sklearn.model_selection import train_test_split

# %%
image_shape = X_train_gray[i].shape

# %%
cnn_model = Sequential()
cnn_model.add(Conv2D(32,3, 3, input_shape = image_shape, activation='relu'))
cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
cnn_model.add(Flatten())
cnn_model.add(Dense(32, activation = 'relu'))
cnn_model.add(Dense(43, activation = 'sigmoid'))

# %%
cnn_model.compile(loss ='sparse_categorical_crossentropy', optimizer=Adam(lr=0.001),metrics =['accuracy'])

# %%
history = cnn_model.fit(X_train_gray_norm,
                        y_train,
                        batch_size=500,
                        epochs=50,
                        verbose=1,
                        validation_data = (X_validation_gray_norm,y_validation))
# Out:
# Epoch 1/50
# 70/70 [==============================] - 1s 10ms/step - loss: 3.5589 - accuracy: 0.0783 - val_loss: 3.4149 - val_accuracy: 0.1370
# Epoch 2/50
# 70/70 [==============================] - 1s 8ms/step - loss: 3.1013 - accuracy: 0.2025 - val_loss: 3.0121 - val_accuracy: 0.2440
# Epoch 3/50
# 70/70 [==============================] - 1s 8ms/step - loss: 2.6119 - accuracy: 0.3306 - val_loss: 2.5972 - val_accuracy: 0.3161
# Epoch 4/50
# 70/70 [==============================] - 1s 8ms/step - loss: 2.1672 - accuracy: 0.4250 - val_loss: 2.2689 - val_accuracy: 0.3975
# Epoch 5/50
# 70/70 [==============================] - 1s 8ms/step - loss: 1.8439 - accuracy: 0.4997 - val_loss: 2.0165 - val_accuracy: 0.4426
# Epoch 6/50
# 70/70 [==============================] - 1s 8ms/step - loss: 1.6133 - accuracy: 0.5571 - val_loss: 1.8219 - val_accuracy: 0.4923
# Epoch 7/50
# 70/70 [==============================] - 1s 8ms/step - loss: 1.4464 - accuracy: 0.5947 - val_loss: 1.7288 - val_accuracy: 0.4980
# Epoch 8/50
# 70/70 [==============================] - 1s 8ms/step - loss: 1.3011 - accuracy: 0.6330 - val_loss: 1.6123 - val_accuracy: 0.5458
# Epoch 9/50
# 70/70 [==============================] - 1s 8ms/step - loss: 1.1862 - accuracy: 0.6682 - val_loss: 1.5490 - val_accuracy: 0.5481
# Epoch 10/50
# 70/70 [==============================] - 1s 8ms/step - loss: 1.0802 - accuracy: 0.6993 - val_loss: 1.5080 - val_accuracy: 0.5701
# Epoch 11/50
# 70/70 [==============================] - 1s 8ms/step - loss: 1.0241 - accuracy: 0.7139 - val_loss: 1.4392 - val_accuracy: 0.5719
# Epoch 12/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.9651 - accuracy: 0.7301 - val_loss: 1.3720 - val_accuracy: 0.6179
# Epoch 13/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.9161 - accuracy: 0.7469 - val_loss: 1.3337 - val_accuracy: 0.6320
# Epoch 14/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8639 - accuracy: 0.7610 - val_loss: 1.3357 - val_accuracy: 0.6254
# Epoch 15/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8348 - accuracy: 0.7645 - val_loss: 1.3015 - val_accuracy: 0.6283
# Epoch 16/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.7945 - accuracy: 0.7777 - val_loss: 1.2524 - val_accuracy: 0.6653
# Epoch 17/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.7536 - accuracy: 0.7944 - val_loss: 1.2282 - val_accuracy: 0.6569
# Epoch 18/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7362 - accuracy: 0.7958 - val_loss: 1.2030 - val_accuracy: 0.6707
# Epoch 19/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.7130 - accuracy: 0.8029 - val_loss: 1.2109 - val_accuracy: 0.6848
# Epoch 20/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6919 - accuracy: 0.8039 - val_loss: 1.1595 - val_accuracy: 0.6844
# Epoch 21/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6616 - accuracy: 0.8183 - val_loss: 1.1634 - val_accuracy: 0.6830
# Epoch 22/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6464 - accuracy: 0.8221 - val_loss: 1.1501 - val_accuracy: 0.6800
# Epoch 23/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6199 - accuracy: 0.8287 - val_loss: 1.1244 - val_accuracy: 0.6823
# Epoch 24/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6232 - accuracy: 0.8293 - val_loss: 1.1105 - val_accuracy: 0.6907
# Epoch 25/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5846 - accuracy: 0.8413 - val_loss: 1.1315 - val_accuracy: 0.6893
# Epoch 26/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5706 - accuracy: 0.8443 - val_loss: 1.1254 - val_accuracy: 0.6977
# Epoch 27/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5716 - accuracy: 0.8427 - val_loss: 1.0954 - val_accuracy: 0.7068
# Epoch 28/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5535 - accuracy: 0.8482 - val_loss: 1.0980 - val_accuracy: 0.7007
# Epoch 29/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5440 - accuracy: 0.8539 - val_loss: 1.0778 - val_accuracy: 0.7220
# Epoch 30/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5183 - accuracy: 0.8596 - val_loss: 1.0643 - val_accuracy: 0.7295
# Epoch 31/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5178 - accuracy: 0.8599 - val_loss: 1.0752 - val_accuracy: 0.7206
# Epoch 32/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5042 - accuracy: 0.8648 - val_loss: 1.0859 - val_accuracy: 0.7109
# Epoch 33/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.4981 - accuracy: 0.8645 - val_loss: 1.0657 - val_accuracy: 0.7240
# Epoch 34/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.4799 - accuracy: 0.8709 - val_loss: 1.0728 - val_accuracy: 0.7088
# Epoch 35/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.4820 - accuracy: 0.8662 - val_loss: 1.0386 - val_accuracy: 0.7420
# Epoch 36/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.4644 - accuracy: 0.8718 - val_loss: 1.0823 - val_accuracy: 0.7120
# Epoch 37/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.4576 - accuracy: 0.8746 - val_loss: 1.0586 - val_accuracy: 0.7392
# Epoch 38/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.4483 - accuracy: 0.8806 - val_loss: 1.0375 - val_accuracy: 0.7417
# Epoch 39/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.4500 - accuracy: 0.8804 - val_loss: 1.0729 - val_accuracy: 0.7365
# Epoch 40/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.4368 - accuracy: 0.8816 - val_loss: 1.0376 - val_accuracy: 0.7415
# Epoch 41/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.4306 - accuracy: 0.8863 - val_loss: 1.0412 - val_accuracy: 0.7469
# Epoch 42/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.4162 - accuracy: 0.8882 - val_loss: 1.0130 - val_accuracy: 0.7492
# Epoch 43/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.4085 - accuracy: 0.8903 - val_loss: 1.0075 - val_accuracy: 0.7612
# Epoch 44/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.4057 - accuracy: 0.8921 - val_loss: 1.0142 - val_accuracy: 0.7492
# Epoch 45/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.4079 - accuracy: 0.8898 - val_loss: 1.0253 - val_accuracy: 0.7444
# Epoch 46/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.3919 - accuracy: 0.8972 - val_loss: 1.0435 - val_accuracy: 0.7356
# Epoch 47/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.3839 - accuracy: 0.8989 - val_loss: 1.0134 - val_accuracy: 0.7574
# Epoch 48/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.3916 - accuracy: 0.8937 - val_loss: 1.0458 - val_accuracy: 0.7429
# Epoch 49/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.3754 - accuracy: 0.8998 - val_loss: 1.0403 - val_accuracy: 0.7252
# Epoch 50/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.3667 - accuracy: 0.9036 - val_loss: 1.0291 - val_accuracy: 0.7503

# %%
score = cnn_model.evaluate(X_test_gray_norm, y_test,verbose=0)
print('Test Accuracy : {:.4f}'.format(score[1]))
# Out:
# Test Accuracy : 0.7390

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
#get the predictions for the test data
predicted_classes = cnn_model.predict_classes(X_test_gray_norm)
#get the indices to be plotted
y_true = y_test

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
cm
# Out:
# array([[ 19,  20,   8, ...,   0,   0,   0],
#        [ 98, 482,  71, ...,   4,   0,   0],
#        [ 77, 117, 467, ...,   2,   0,   0],
#        ...,
#        [  6,   4,  16, ...,  27,   0,   0],
#        [  0,   0,   2, ...,   0,  15,   0],
#        [  0,   0,   0, ...,   0,  23,  42]], dtype=int64)

# %%
for i in range(0,12):
    plt.subplot(4,3,i+1)
    plt.imshow(X_test_gray_norm[i+10].squeeze(), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[i+10], y_true[i+10]))
    plt.tight_layout()
